# %% [markdown]
# <a href="https://colab.research.google.com/github/josuemarroquinj/enterprise-risk-stress-testing-santander/blob/main/notebooks/00_project_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Enterprise Risk Management & Financial Stress Testing
# ## A Reproducible Case Study of Banco Santander
#
# ### Notebook 00 — Project Setup
#
# This notebook initializes the analytical environment for the project.
#
# The study develops a reproducible Enterprise Risk Management (ERM) and
# financial stress-testing framework using publicly available information
# from Banco Santander's 2025 Annual Report.
#
# ### Objectives
#
# - Configure the Python environment.
# - Define the project structure.
# - Establish reproducibility standards.
# - Prepare the analytical workflow.
# - Separate reported data, derived metrics and analytical assumptions.
#
# ### Disclaimer
#
# This project is an academic case study developed for educational and
# research purposes. It does not represent an official risk assessment of
# Banco Santander and does not constitute investment, financial or
# regulatory advice.

# %%
# ============================================================
# 00. PROJECT SETUP
# Enterprise Risk Management & Financial Stress Testing
# Banco Santander Case Study
# ============================================================

import sys
import platform

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("Python version:", sys.version.split()[0])
print("Platform:", platform.platform())
print("NumPy version:", np.__version__)
print("Pandas version:", pd.__version__)

print("\nEnvironment successfully initialized.")
# Out:
# Python version: 3.13.15
# Platform: Linux-6.6.122+-x86_64-with-glibc2.35
# NumPy version: 2.1.3
# Pandas version: 2.2.3
#
# Environment successfully initialized.
